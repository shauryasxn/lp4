# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.losses import MeanSquaredLogarithmicError

# %% [markdown]
# # Loading Data

# %%
data = pd.read_csv("/content/creditcard.csv")
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# # Exploring Data

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
data = data.drop(['Class', 'Time'], axis=1)

data
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V20       V21  \
# 0       0.239599  0.098698  0.363787  0.090794  ...  0.251412 -0.018307
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.524980  0.247998
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300
# 4       0.592941 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  1.475829  0.213454
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.059616  0.214205
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.001396  0.232045
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.127434  0.265245
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.382948  0.261057
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 0       0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1      -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2       0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3       0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4       0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.111864  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731
# 284803  0.924384  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527
# 284804  0.578229 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561
# 284805  0.800049 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533
# 284806  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649
#
#         Amount
# 0       149.62
# 1         2.69
# 2       378.66
# 3       123.50
# 4        69.99
# ...        ...
# 284802    0.77
# 284803   24.79
# 284804   67.88
# 284805   10.00
# 284806  217.00
#
# [284807 rows x 29 columns]

# %%
x_train, x_test = train_test_split(data, test_size=0.2)

print(x_train.shape[1])
print(x_test.shape[1])
# Out:
# 29
# 29

# %%
min_max_scaler = MinMaxScaler(feature_range=(0,1))

x_train_scaled = min_max_scaler.fit_transform(x_train.copy())
x_test_scaled = min_max_scaler.transform(x_test.copy())

# %% [markdown]
# # Defining Model

# %%
#creating autoencoder subclass by extending Model class from keras
class AutoEncoder(Model):  #extending Model class
  def __init__(self, output_units, ldim=8):
    super().__init__()
    self.encoder = Sequential([
      Dense(64, activation='relu'),
      Dropout(0.1),
      Dense(32, activation='relu'),
      Dropout(0.1),
      Dense(16, activation='relu'),
      Dropout(0.1),
      Dense(ldim, activation='relu')  #ldim = 8
    ])
    self.decoder = Sequential([
      Dense(16, activation='relu'),
      Dropout(0.1),
      Dense(32, activation='relu'),
      Dropout(0.1),
      Dense(64, activation='relu'),
      Dropout(0.1),
      Dense(output_units, activation='sigmoid') # binary isliye sigmoid
    ])

  def call(self, inputs):
    encoded = self.encoder(inputs)
    decoded = self.decoder(encoded)
    return decoded

# %% [markdown]
# # Training Model

# %%
#model configuration
model = AutoEncoder(output_units=x_train_scaled.shape[1])
model.compile(loss='msle', metrics=['mse'], optimizer='adam')
epochs = 20

history = model.fit(
    x_train_scaled,
    x_train_scaled,
    epochs=epochs,
    batch_size=256,
    validation_data=(x_test_scaled, x_test_scaled)
)
# Out:
# Epoch 1/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0031 - mse: 0.0066 - val_loss: 7.2635e-04 - val_mse: 0.0015
# Epoch 2/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 6.0857e-04 - mse: 0.0013 - val_loss: 4.3565e-04 - val_mse: 9.5668e-04
# Epoch 3/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 4.1282e-04 - mse: 9.1346e-04 - val_loss: 3.7184e-04 - val_mse: 8.5384e-04
# Epoch 4/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.3574e-04 - mse: 7.7838e-04 - val_loss: 3.2190e-04 - val_mse: 7.4675e-04
# Epoch 5/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 3.1105e-04 - mse: 7.2445e-04 - val_loss: 3.2246e-04 - val_mse: 7.4579e-04
# Epoch 6/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 3.0381e-04 - mse: 7.0903e-04 - val_loss: 3.0755e-04 - val_mse: 7.1970e-04
# Epoch 7/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 2.9453e-04 - mse: 6.8950e-04 - val_loss: 3.0298e-04 - val_mse: 7.0061e-04
# Epoch 8/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2.5448e-04 - mse: 6.0237e-04 - val_loss: 2.2089e-04 - val_mse: 5.3044e-04
# Epoch 9/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 2.1826e-04 - mse: 5.2513e-04 - val_loss: 2.2687e-04 - val_mse: 5.4277e-04
# Epoch 10/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 2.1301e-04 - mse: 5.1513e-04 - val_loss: 2.1013e-04 - val_mse: 5.0981e-04
# Epoch 11/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2.0570e-04 - mse: 5.0028e-04 - val_loss: 2.1170e-04 - val_mse: 5.1355e-04
# Epoch 12/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.0248e-04 - mse: 4.9355e-04 - val_loss: 2.0906e-04 - val_mse: 5.0790e-04
# Epoch 13/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.9728e-04 - mse: 4.8231e-04 - val_loss: 2.0499e-04 - val_mse: 5.0097e-04
# Epoch 14/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9315e-04 - mse: 4.7281e-04 - val_loss: 1.8994e-04 - val_mse: 4.6501e-04
# Epoch 15/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 1.8775e-04 - mse: 4.5982e-04 - val_loss: 1.8618e-04 - val_mse: 4.5630e-04
# Epoch 16/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.8573e-04 - mse: 4.5431e-04 - val_loss: 1.9681e-04 - val_mse: 4.7723e-04
# Epoch 17/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.8454e-04 - mse: 4.5091e-04 - val_loss: 2.3453e-04 - val_mse: 5.5380e-04
# Epoch 18/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 1.8169e-04 - mse: 4.4333e-04 - val_loss: 1.9724e-04 - val_mse: 4.7554e-04
# Epoch 19/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.7903e-04 - mse: 4.3619e-04 - val_loss: 1.9206e-04 - val_mse: 4.6181e-04
# Epoch 20/20
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1.7777e-04 - mse: 4.3236e-04 - val_loss: 1.8855e-04 - val_mse: 4.5345e-04

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('MSLE Loss')
plt.legend(['loss', 'val_loss'])
plt.show()

# %% [markdown]
# # Finding Threshold

# %%
predictions = model.predict(x_test)
mse = np.mean(np.power(x_test - predictions, 2), axis=1)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step

# %%
threshold = np.percentile(mse, 95)  # Adjust the percentile as needed
threshold
# Out:
# 4619.202956608948

# %%
anomalies = mse > threshold

# Calculate the number of anomalies
num_anomalies = np.sum(anomalies)
print(f"Number of Anomalies: {num_anomalies}")
# Out:
# Number of Anomalies: 2849

# %%
#Plot the anomalies
import matplotlib.pyplot as plt
# plt.figure(figsize=(12, 6))
plt.plot(mse, color='g',marker='o', linestyle='', markersize=3, label='MSE', )
plt.axhline(threshold, color='y', linestyle='--', label='Anomaly Threshold')
plt.xlabel('Sample Index')
plt.ylabel('MSE')
plt.title('Anomaly Detection Results')
plt.legend()
plt.show()
